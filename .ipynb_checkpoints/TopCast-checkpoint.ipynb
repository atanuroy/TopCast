# %%
from bs4 import BeautifulSoup
import requests
import urllib

# %%
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)

# get the table for the top 250

table = soup.find('div', attrs={'class': 'lister'})
tid_name_rank_dict = {}
for row in table.findAll('tr'):
#     print row
    title = row.find('td', attrs={'class':'titleColumn'})
    if title is not None:
#         print title
        rank =  int(title.next.strip(' \n.'))

        title_vals = title.find('a', href = True)
        tid = title_vals['href'].split('/')[2]
        tid = tid.strip('\'')
        name = title_vals.contents
        
#         Create the dictionaries
        tid_name_rank_dict[tid] = (name, rank)

#         print rank
#         print tid
#         print name
#         print title_vals
#     print '--------\n'
# Out:
# /Users/aroy/anaconda/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
tid_name_rank_dict
# Out:
# {'tt0012349': ([u'The Kid'], 96),
#  'tt0015864': ([u'The Gold Rush'], 130),
#  'tt0017136': ([u'Metropolis'], 104),
#  'tt0017925': ([u'The General'], 141),
#  'tt0018455': ([u'Sunrise'], 138),
#  'tt0021749': ([u'City Lights'], 35),
#  'tt0022100': ([u'M'], 74),
#  'tt0025316': ([u'It Happened One Night'], 172),
#  'tt0027977': ([u'Modern Times'], 37),
#  'tt0031381': ([u'Gone with the Wind'], 158),
#  'tt0031679': ([u'Mr. Smith Goes to Washington'], 131),
#  'tt0032138': ([u'The Wizard of Oz'], 216),
#  'tt0032551': ([u'The Grapes of Wrath'], 202),
#  'tt0032553': ([u'The Great Dictator'], 54),
#  'tt0032976': ([u'Rebecca'], 157),
#  'tt0033467': ([u'Citizen Kane'], 67),
#  'tt0033870': ([u'The Maltese Falcon'], 179),
#  'tt0034583': ([u'Casablanca'], 32),
#  'tt0036775': ([u'Double Indemnity'], 81),
#  'tt0036868': ([u'The Best Years of Our Lives'], 221),
#  'tt0038650': ([u"It's a Wonderful Life"], 24),
#  'tt0040522': ([u'Bicycle Thieves'], 90),
#  'tt0040897': ([u'The Treasure of the Sierra Madre'], 111),
#  'tt0041546': ([u'Kind Hearts and Coronets'], 228),
#  'tt0041959': ([u'The Third Man'], 115),
#  'tt0042192': ([u'All About Eve'], 106),
#  'tt0042876': ([u'Rash\xf4mon'], 99),
#  'tt0043014': ([u'Sunset Blvd.'], 52),
#  'tt0044079': ([u'Strangers on a Train'], 224),
#  'tt0044706': ([u'High Noon'], 248),
#  'tt0044741': ([u'Ikiru'], 128),
#  'tt0045152': ([u"Singin' in the Rain"], 91),
#  'tt0046250': ([u'Roman Holiday'], 243),
#  'tt0046268': ([u'The Wages of Fear'], 180),
#  'tt0046438': ([u'Tokyo Story'], 149),
#  'tt0046911': ([u'Diabolique'], 210),
#  'tt0046912': ([u'Dial M for Murder'], 156),
#  'tt0047296': ([u'On the Waterfront'], 126),
#  'tt0047396': ([u'Rear Window'], 40),
#  'tt0047478': ([u'Seven Samurai'], 19),
#  'tt0050083': ([u'12 Angry Men'], 6),
#  'tt0050212': ([u'The Bridge on the River Kwai'], 132),
#  'tt0050613': ([u'Throne of Blood'], 247),
#  'tt0050783': ([u'Nights of Cabiria'], 176),
#  'tt0050825': ([u'Paths of Glory'], 57),
#  'tt0050976': ([u'The Seventh Seal'], 135),
#  'tt0050986': ([u'Wild Strawberries'], 140),
#  'tt0051201': ([u'Witness for the Prosecution'], 72),
#  'tt0052311': ([u'Touch of Evil'], 198),
#  'tt0052357': ([u'Vertigo'], 71),
#  'tt0052618': ([u'Ben-Hur'], 197),
#  'tt0053125': ([u'North by Northwest'], 70),
#  'tt0053198': ([u'The 400 Blows'], 187),
#  'tt0053291': ([u'Some Like It Hot'], 112),
#  'tt0053604': ([u'The Apartment'], 100),
#  'tt0054215': ([u'Psycho'], 34),
#  'tt0055031': ([u'Judgment at Nuremberg'], 144),
#  'tt0055630': ([u'Yojimbo'], 107),
#  'tt0056172': ([u'Lawrence of Arabia'], 82),
#  'tt0056592': ([u'To Kill a Mockingbird'], 84),
#  'tt0056801': ([u'8\xbd'], 214),
#  'tt0057012': ([u'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb'],
#   51),
#  'tt0057115': ([u'The Great Escape'], 121),
#  'tt0058461': ([u'A Fistful of Dollars'], 240),
#  'tt0058946': ([u'The Battle of Algiers'], 231),
#  'tt0059578': ([u'For a Few Dollars More'], 98),
#  'tt0060196': ([u'The Good, the Bad and the Ugly'], 9),
#  'tt0060827': ([u'Persona'], 190),
#  'tt0061512': ([u'Cool Hand Luke'], 160),
#  'tt0062622': ([u'2001: A Space Odyssey'], 89),
#  'tt0064115': ([u'Butch Cassidy and the Sundance Kid'], 184),
#  'tt0064116': ([u'Once Upon a Time in the West'], 28),
#  'tt0066921': ([u'A Clockwork Orange'], 79),
#  'tt0068646': ([u'The Godfather'], 2),
#  'tt0070735': ([u'The Sting'], 88),
#  'tt0071315': ([u'Chinatown'], 122),
#  'tt0071562': ([u'The Godfather: Part II'], 3),
#  'tt0071853': ([u'Monty Python and the Holy Grail'], 95),
#  'tt0072684': ([u'Barry Lyndon'], 230),
#  'tt0072890': ([u'Dog Day Afternoon'], 232),
#  'tt0073195': ([u'Jaws'], 225),
#  'tt0073486': ([u"One Flew Over the Cuckoo's Nest"], 16),
#  'tt0074896': ([u'The Message'], 159),
#  'tt0074958': ([u'Network'], 181),
#  'tt0075148': ([u'Rocky'], 213),
#  'tt0075314': ([u'Taxi Driver'], 80),
#  'tt0075686': ([u'Annie Hall'], 203),
#  'tt0076759': ([u'Star Wars: Episode IV - A New Hope'], 20),
#  'tt0077416': ([u'The Deer Hunter'], 153),
#  'tt0078748': ([u'Alien'], 53),
#  'tt0078788': ([u'Apocalypse Now'], 48),
#  'tt0079470': ([u'Life of Brian'], 173),
#  'tt0079944': ([u'Stalker'], 204),
#  'tt0080678': ([u'The Elephant Man'], 142),
#  'tt0080684': ([u'Star Wars: Episode V - The Empire Strikes Back'], 12),
#  'tt0081398': ([u'Raging Bull'], 117),
#  'tt0081505': ([u'The Shining'], 59),
#  'tt0082096': ([u'Das Boot'], 69),
#  'tt0082971': ([u'Raiders of the Lost Ark'], 36),
#  'tt0083658': ([u'Blade Runner'], 134),
#  'tt0083922': ([u'Fanny and Alexander'], 239),
#  'tt0083987': ([u'Gandhi'], 208),
#  'tt0084787': ([u'The Thing'], 164),
#  'tt0086190': ([u'Star Wars: Episode VI - Return of the Jedi'], 73),
#  'tt0086250': ([u'Scarface'], 101),
#  'tt0086879': ([u'Amadeus'], 86),
#  'tt0087544': ([u'Nausica\xe4 of the Valley of the Wind'], 201),
#  'tt0087843': ([u'Once Upon a Time in America'], 68),
#  'tt0088247': ([u'The Terminator'], 218),
#  'tt0088763': ([u'Back to the Future'], 44),
#  'tt0089881': ([u'Ran'], 129),
#  'tt0090605': ([u'Aliens'], 64),
#  'tt0091251': ([u'Come and See'], 165),
#  'tt0091763': ([u'Platoon'], 178),
#  'tt0092005': ([u'Stand by Me'], 188),
#  'tt0092067': ([u'Castle in the Sky'], 242),
#  'tt0093058': ([u'Full Metal Jacket'], 87),
#  'tt0093779': ([u'The Princess Bride'], 196),
#  'tt0095016': ([u'Die Hard'], 119),
#  'tt0095327': ([u'Grave of the Fireflies'], 60),
#  'tt0095765': ([u'Cinema Paradiso'], 56),
#  'tt0096283': ([u'My Neighbor Totoro'], 127),
#  'tt0097576': ([u'Indiana Jones and the Last Crusade'], 102),
#  'tt0099685': ([u'Goodfellas'], 17),
#  'tt0101414': ([u'Beauty and the Beast'], 250),
#  'tt0102926': ([u'The Silence of the Lambs'], 23),
#  'tt0103064': ([u'Terminator 2: Judgment Day'], 41),
#  'tt0105236': ([u'Reservoir Dogs'], 75),
#  'tt0105695': ([u'Unforgiven'], 114),
#  'tt0107048': ([u'Groundhog Day'], 222),
#  'tt0107207': ([u'In the Name of the Father'], 189),
#  'tt0107290': ([u'Jurassic Park'], 200),
#  'tt0108052': ([u"Schindler's List"], 5),
#  'tt0109830': ([u'Forrest Gump'], 13),
#  'tt0110357': ([u'The Lion King'], 50),
#  'tt0110413': ([u'L\xe9on: The Professional'], 27),
#  'tt0110912': ([u'Pulp Fiction'], 7),
#  'tt0111161': ([u'The Shawshank Redemption'], 1),
#  'tt0112471': ([u'Before Sunrise'], 205),
#  'tt0112573': ([u'Braveheart'], 76),
#  'tt0112641': ([u'Casino'], 139),
#  'tt0113247': ([u'La Haine'], 227),
#  'tt0113277': ([u'Heat'], 123),
#  'tt0114369': ([u'Se7en'], 22),
#  'tt0114709': ([u'Toy Story'], 92),
#  'tt0114746': ([u'Twelve Monkeys'], 220),
#  'tt0114814': ([u'The Usual Suspects'], 25),
#  'tt0116282': ([u'Fargo'], 155),
#  'tt0117951': ([u'Trainspotting'], 154),
#  'tt0118715': ([u'The Big Lebowski'], 152),
#  'tt0118799': ([u'Life Is Beautiful'], 26),
#  'tt0118849': ([u'Children of Heaven'], 116),
#  'tt0119217': ([u'Good Will Hunting'], 110),
#  'tt0119488': ([u'L.A. Confidential'], 97),
#  'tt0119698': ([u'Princess Mononoke'], 65),
#  'tt0120382': ([u'The Truman Show'], 209),
#  'tt0120586': ([u'American History X'], 31),
#  'tt0120689': ([u'The Green Mile'], 39),
#  'tt0120735': ([u'Lock, Stock and Two Smoking Barrels'], 136),
#  'tt0120737': ([u'The Lord of the Rings: The Fellowship of the Ring'], 11),
#  'tt0120815': ([u'Saving Private Ryan'], 30),
#  'tt0133093': ([u'The Matrix'], 18),
#  'tt0137523': ([u'Fight Club'], 10),
#  'tt0167260': ([u'The Lord of the Rings: The Return of the King'], 8),
#  'tt0167261': ([u'The Lord of the Rings: The Two Towers'], 15),
#  'tt0167404': ([u'The Sixth Sense'], 163),
#  'tt0169102': ([u'Lagaan: Once Upon a Time in India'], 249),
#  'tt0169547': ([u'American Beauty'], 63),
#  'tt0172495': ([u'Gladiator'], 46),
#  'tt0180093': ([u'Requiem for a Dream'], 78),
#  'tt0198781': ([u'Monsters, Inc.'], 215),
#  'tt0208092': ([u'Snatch'], 93),
#  'tt0209144': ([u'Memento'], 47),
#  'tt0211915': ([u'Am\xe9lie'], 77),
#  'tt0245429': ([u'Spirited Away'], 29),
#  'tt0245712': ([u'Amores Perros'], 193),
#  'tt0246578': ([u'Donnie Darko'], 212),
#  'tt0253474': ([u'The Pianist'], 43),
#  'tt0264464': ([u'Catch Me If You Can'], 233),
#  'tt0266543': ([u'Finding Nemo'], 162),
#  'tt0266697': ([u'Kill Bill: Vol. 1'], 170),
#  'tt0268978': ([u'A Beautiful Mind'], 145),
#  'tt0317248': ([u'City of God'], 21),
#  'tt0325980': ([u'Pirates of the Caribbean: The Curse of the Black Pearl'],
#   237),
#  'tt0338013': ([u'Eternal Sunshine of the Spotless Mind'], 85),
#  'tt0338564': ([u'Infernal Affairs'], 223),
#  'tt0347149': ([u"Howl's Moving Castle"], 137),
#  'tt0353969': ([u'Memories of Murder'], 207),
#  'tt0361748': ([u'Inglourious Basterds'], 94),
#  'tt0363163': ([u'Downfall'], 118),
#  'tt0364569': ([u'Oldeuboi'], 66),
#  'tt0372784': ([u'Batman Begins'], 109),
#  'tt0395169': ([u'Hotel Rwanda'], 177),
#  'tt0401792': ([u'Sin City'], 226),
#  'tt0405094': ([u'The Lives of Others'], 55),
#  'tt0405159': ([u'Million Dollar Baby'], 194),
#  'tt0407887': ([u'The Departed'], 42),
#  'tt0434409': ([u'V for Vendetta'], 148),
#  'tt0435761': ([u'Toy Story 3'], 83),
#  'tt0440963': ([u'The Bourne Ultimatum'], 206),
#  'tt0457430': ([u"Pan's Labyrinth"], 125),
#  'tt0468569': ([u'The Dark Knight'], 4),
#  'tt0469494': ([u'There Will Be Blood'], 174),
#  'tt0477348': ([u'No Country for Old Men'], 166),
#  'tt0482571': ([u'The Prestige'], 49),
#  'tt0758758': ([u'Into the Wild'], 167),
#  'tt0816692': ([u'Interstellar'], 33),
#  'tt0848228': ([u'The Avengers'], 244),
#  'tt0892769': ([u'How to Train Your Dragon'], 161),
#  'tt0910970': ([u'WALL\xb7E'], 61),
#  'tt0978762': ([u'Mary and Max'], 168),
#  'tt0993846': ([u'The Wolf of Wall Street'], 146),
#  'tt1028532': ([u"Hachi: A Dog's Tale"], 199),
#  'tt1049413': ([u'Up'], 113),
#  'tt1130884': ([u'Shutter Island'], 186),
#  'tt1187043': ([u'3 Idiots'], 105),
#  'tt1201607': ([u'Harry Potter and the Deathly Hallows: Part 2'], 217),
#  'tt1205489': ([u'Gran Torino'], 151),
#  'tt1220719': ([u'Yip Man'], 235),
#  'tt1255953': ([u'Incendies'], 150),
#  'tt1291584': ([u'Warrior'], 143),
#  'tt1305806': ([u'The Secret in Their Eyes'], 133),
#  'tt1345836': ([u'The Dark Knight Rises'], 62),
#  'tt1375666': ([u'Inception'], 14),
#  'tt1392190': ([u'Mad Max: Fury Road'], 183),
#  'tt1392214': ([u'Prisoners'], 229),
#  'tt1431045': ([u'Deadpool'], 211),
#  'tt1454029': ([u'The Help'], 238),
#  'tt1504320': ([u"The King's Speech"], 246),
#  'tt1663202': ([u'The Revenant'], 219),
#  'tt1675434': ([u'The Intouchables'], 38),
#  'tt1832382': ([u'Jodaeiye Nader az Simin'], 103),
#  'tt1853728': ([u'Django Unchained'], 58),
#  'tt1895587': ([u'Spotlight'], 182),
#  'tt1954470': ([u'Gangs of Wasseypur'], 245),
#  'tt1979320': ([u'Rush'], 175),
#  'tt2015381': ([u'Guardians of the Galaxy'], 241),
#  'tt2024544': ([u'12 Years a Slave'], 191),
#  'tt2084970': ([u'The Imitation Game'], 236),
#  'tt2096673': ([u'Inside Out'], 120),
#  'tt2106476': ([u'Jagten'], 108),
#  'tt2267998': ([u'Gone Girl'], 169),
#  'tt2278388': ([u'The Grand Budapest Hotel'], 192),
#  'tt2488496': ([u'Star Wars: The Force Awakens'], 147),
#  'tt2582802': ([u'Whiplash'], 45),
#  'tt2948356': ([u'Zootopia'], 185),
#  'tt3011894': ([u'Relatos salvajes'], 195),
#  'tt3170832': ([u'Room'], 124),
#  'tt3498820': ([u'Captain America: Civil War'], 171),
#  'tt3659388': ([u'The Martian'], 234)}

# %%
pid = 'nm0000233'
url = 'http://www.imdb.com/name/' + pid
response = requests.get(url)
html = response.content
soup_name = BeautifulSoup(html)

# %%
# Find name 
name = soup_name.find('span', attrs={'class': 'itemprop'}).contents[0]
print name
# Out:
# Quentin Tarantino

# %%
jumpto = soup_name.find('div', attrs={'id': 'jumpto'})
types = jumpto.findAll('a')
# for t in types:
#     print t.contents[0]
#     print '---'

# %%
filmg = soup_name.find('div', attrs={'id': 'filmography'})
# print filmg
categories = filmg.findAll('div', attrs={'class': 'filmo-category-section'})

flag = True
for t,category in zip(types, categories):
#     print t.contents[0]
    movies = category.findAll('b')
#     print len(movies)
    list_of_types = []
    for movie in movies:
#         tid_l = '\'' +  movie.contents[0]['href'].split('/')[2] + '\''
        tid_l = unicode(movie.contents[0]['href'].split('/')[2], "utf-8")
#         print tid_l
#         print movie.contents[0].contents[0]
        if tid_l in tid_name_rank_dict:
#             print '-------\n\n' 
            list_of_types.append(tid_name_rank_dict[tid_l])
    
    if len(list_of_types) > 0:
        flag = False
        print 'As', t.contents[0]
        sorted_list_movies = sorted(list_of_types, key = lambda x: x[1])
        for mov, rank in sorted_list_movies:
            print rank, mov[0]
        print '----------\n'

if flag:
    print 'Sorry', name, 'doesn\'t appear in any Top 250 movie'
# Out:
# As Writer
# 7 Pulp Fiction
# 58 Django Unchained
# 75 Reservoir Dogs
# 94 Inglourious Basterds
# 170 Kill Bill: Vol. 1
# ----------
#
# As Actor
# 7 Pulp Fiction
# 58 Django Unchained
# 75 Reservoir Dogs
# 94 Inglourious Basterds
# ----------
#
# As Director
# 7 Pulp Fiction
# 58 Django Unchained
# 75 Reservoir Dogs
# 94 Inglourious Basterds
# 170 Kill Bill: Vol. 1
# 226 Sin City
# ----------
#
# As Soundtrack
# 58 Django Unchained
# ----------
#
# As Music department
# 170 Kill Bill: Vol. 1
# ----------

# %%
# Search button for imdb

search_item = 'Quentin tarantino'
# search_item = ';;;;;'

search_item = urllib.quote_plus(search_item)
search_url = 'http://www.imdb.com/find?q=' + search_item
s_response = requests.get(search_url)
s_html = s_response.content
s_soup = BeautifulSoup(s_html)

# %%
findname = s_soup.findAll('div', attrs={'class': 'findSection'})
flag_name = False
for eachname in findname:
    c = eachname.findChild('h3', attrs={'class':'findSectionHeader'}).findChild('a')['name']
    if c == 'nm':
        flag_name = True
        name_result = eachname.find('td', attrs = {'class':'result_text'})
        print 'http://www.imdb.com/name/' + name_result.find('a', href=True)['href'].split('/')[2]
        print name_result.find('a', href=True).contents[0]
if not(flag_name):
    print 'IMDB couldn\'t find a film personality with your search string'
# Out:
# http://www.imdb.com/name/nm0000233
# Quentin Tarantino
